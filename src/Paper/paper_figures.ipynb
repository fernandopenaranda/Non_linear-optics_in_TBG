# %%
include("compute_main.jl")              # presets
include("comupte_supplementary.jl")     # presets
include("figures_main.jl")              # plotting functions
include("figures_supplementary.jl")     # plotting functions

# %% [markdown]
# ## Figures: Main

# %% [markdown]
# ### Figure 1

# %% [markdown]
# #### Compute

# %%
shift(fig0a1, cfig0)
shift(fig0a2, cfig0)

# %% [markdown]
# #### Plot

# %%
str1 = "2024_01_13T18_08_25_211_arrays.csv"
str2 = "2024_01_13T19_06_29_115_arrays.csv"

# %%
fig1 = dosplot(str1, str2)

# %% [markdown]
# ### Figure 2

# %% [markdown]
# #### Compute

# %%
anglesweep(fig1a, cfig1, method = :SHIFT, steps = 15) # Panel A
anglesweep(fig1b, cfig1, method = :SHIFT, steps = 15) # Panel B
anglesweep(fig1a, cfig1, method = :INJECTION, steps = 15) # Panel C
anglesweep(fig1b, cfig1, method = :INJECTION, steps = 15) # Panel D
anglesweep(fig2a1, cfig2a)
anglesweep(fig2a2, cfig2a)
anglesweep(fig2a3, cfig2a)

anglesweep(fig2b1, cfig2b)
anglesweep(fig2b2, cfig2b)
anglesweep(fig2b3, cfig2b)

anglesweep(fig2c1, cfig2c)
anglesweep(fig2c2, cfig2c)
anglesweep(fig2c3, cfig2c)

anglesweep(fig2c1, cfig2c, method = :INJECTION)
anglesweep(fig2c2, cfig2c, method = :INJECTION)
anglesweep(fig2c3, cfig2c, method = :INJECTION)


# Focus fig2

## panel A
shift(System(fig2a1, θ = 1.05), cfig2a)
shift(System(fig2a1, θ = 1.11), cfig2a)

shift(System(fig2a2, θ = 1.05), cfig2a)
shift(System(fig2a2, θ = 1.11), cfig2a)

shift(System(fig2a3, θ = 1.05), cfig2a)
shift(System(fig2a3, θ = 1.11), cfig2a)

## panel B
shift(System(fig2b1, θ = 1.05), cfig2b)
shift(System(fig2b1, θ = 1.11), cfig2b)

shift(System(fig2b2, θ = 1.05), cfig2b)
shift(System(fig2b2, θ = 1.11), cfig2b)

shift(System(fig2b3, θ = 1.05), cfig2b)
shift(System(fig2b3, θ = 1.11), cfig2b)

## panel C
shift(System(fig2c1, θ = 1.05), cfig2c)         
shift(System(fig2c1, θ = 1.11), cfig2c)

shift(System(fig2c2, θ = 1.05), cfig2c)
shift(System(fig2c2, θ = 1.11), cfig2c)

shift(System(fig2c3, θ = 1.05), cfig2c)
shift(System(fig2c3, θ = 1.11), cfig2c)

## panel D
injection(System(fig2c1, θ = 1.05), cfig2c)
injection(System(fig2c1, θ = 1.11), cfig2c)

injection(System(fig2c2, θ = 1.05), cfig2c)
injection(System(fig2c2, θ = 1.11), cfig2c)

injection(System(fig2c3, θ = 1.05), cfig2c)
injection(System(fig2c3, θ = 1.11), cfig2c)

# %% [markdown]
# #### Plot

# %%
strpath2a = [ "2024_01_04T16_36_14_280_arrays.csv",
    "2024_01_04T17_23_04_987_arrays.csv",
    "2024_01_04T17_57_12_276_arrays.csv",
    "2024_01_04T18_29_30_607_arrays.csv",
    "2024_01_04T19_25_49_657_arrays.csv",
    "2024_01_05T03_58_39_280_arrays.csv",
    "2024_01_05T10_09_17_114_arrays.csv",
    "2024_01_05T10_57_34_852_arrays.csv",
    "2024_01_05T11_28_57_688_arrays.csv",
    "2024_01_05T12_01_03_138_arrays.csv",
    "2024_01_05T12_34_47_500_arrays.csv",
strpath3b = ["2024_01_11T16_50_14_537_arrays.csv",
    "2024_01_11T20_04_23_201_arrays.csv",
    "2024_01_12T01_30_24_661_arrays.csv",
    "2024_01_12T10_44_04_088_arrays.csv",
    "2024_01_12T12_51_04_320_arrays.csv",
    "2024_01_12T16_35_22_312_arrays.csv"]

strpath3c = [
    "2024_01_17T14_49_39_611_arrays.csv",
    "2024_01_17T13_36_24_974_arrays.csv",
    "2024_01_17T10_03_49_499_10_average_string_arrays.csv",
    "2024_01_18T09_47_06_163_17_average_string_arrays.csv",
    "2024_01_12T20_35_13_025_arrays.csv",
    "2024_01_17T10_00_08_377_arrays.csv"]

strpath3d = [
    "2024_01_18T11_53_21_553_arrays.csv",
    "2024_01_18T12_36_58_943_arrays.csv",
    "2023_12_31T12_59_28_790_arrays.csv",
    "2023_12_31T14_09_34_968_arrays.csv",
    "2023_12_31T14_19_41_723_arrays.csv",
    "2023_12_31T15_33_37_921_arrays.csv"]

# %%
fig3 = lat_fig3(strpath3a, strpath3b, strpath3c, strpath3d)

# %% [markdown]
# ### Figure 4

# %% [markdown]
# #### Compute

# %%
shift(System(fig1a, θ = 1.055, mass_term = :kang_vafek_mass), cfig1)
shift(System(fig1a, θ = 1.115,  mass_term = :kang_vafek_mass), cfig1)

shift(System(fig1b, θ = 1.055, mass_term = :kang_vafek_mass), cfig1)
shift(System(fig1b, θ = 1.115,  mass_term = :kang_vafek_mass), cfig1)

injection(System(fig1a, θ = 1.055, mass_term = :kang_vafek_mass), cfig1)
injection(System(fig1a, θ = 1.115,  mass_term = :kang_vafek_mass), cfig1)

injection(System(fig1b, θ = 1.055, mass_term = :kang_vafek_mass), cfig1)
injection(System(fig1b, θ = 1.115,  mass_term = :kang_vafek_mass), cfig1)

# %% [markdown]
# #### Plot

# %%
normalmass = "2024_01_09T14_01_36_560_arrays.csv"
kaplanmass = "2024_01_03T13_28_10_346_arrays.csv"
szvafekposmass = "2024_01_04T12_19_17_248_arrays.csv"
szvafeknegmass = "2024_01_03T15_15_56_065_arrays.csv"

# %%
fig4 = lat_fig4(normalmass, kaplanmass, szvafekposmass, szvafeknegmass)

# %% [markdown]
# ## Supplementary

# %% [markdown]
# ### Figure S1

# %% [markdown]
# #### Compute

# %%
computation_S1()

# %% [markdown]
# #### Plot

# %%
str_mat =["2024_06_10T00_06_44_891_arrays.csv",
    "2024_06_10T00_06_44_985_arrays.csv",
    "2024_06_10T13_01_29_082_arrays.csv",
    "2024_06_10T13_01_29_137_arrays.csv",
    "2024_06_10T17_27_15_708_arrays.csv",
    "2024_06_10T17_27_15_774_arrays.csv",
    "2024_06_10T16_19_56_410_arrays.csv",
    "2024_06_10T16_19_56_509_arrays.csv",
    "2024_06_10T12_41_37_653_arrays.csv",
    "2024_06_10T12_41_37_714_arrays.csv",
    "2024_06_10T14_16_41_145_arrays.csv",
    "2024_06_10T14_16_41_199_arrays.csv",
    "2024_06_10T17_47_46_621_arrays.csv",
    "2024_06_10T17_47_46_695_arrays.csv",
    "2024_06_10T16_40_15_320_arrays.csv",
    "2024_06_10T16_40_15_421_arrays.csv"]

# %%
figS1 = lat_suppl1(str_mat)

# %% [markdown]
# ### Figure S2 and S3

# %% [markdown]
# #### Compute

# %%
## panel A

shift(System(fig2a3, θ = 1.055, mass_term = :szvafek), cfig2a)
shift(System(fig2a3, θ = 1.115, mass_term = :szvafek), cfig2a)

## panel B
shift(System(fig2b3, θ = 1.055, mass_term = :sztauzvafek), cfig2b)
shift(System(fig2b3, θ = 1.115, mass_term = :sztauzvafek), cfig2b)

## panel C
shift(System(fig2c3, θ = 1.055, mass_term = :tauzvafek), cfig2c)
shift(System(fig2c3, θ = 1.115, mass_term = :tauzvafek), cfig2c)

## panel D
injection(System(fig2c3, θ = 1.055, mass_term = :tauzvafek), cfig2c)
injection(System(fig2c3, θ = 1.115, mass_term = :tauzvafek), cfig2c)

# %% [markdown]
# #### Plot

# %%
# s2
shiftxyz_mu0_btheta = "2024_02_05T12_25_38_923_arrays.csv"
shiftxyz_mu0_atheta = "2024_02_05T14_29_59_270_arrays.csv"
shiftxyz_mu0_btheta_ref = "2024_01_04T16_36_14_280_arrays.csv" 
shiftxyz_mu0_atheta_ref = "2024_01_05T15_43_12_306_arrays.csv"
shiftxyz_mu_btheta_ref = "2024_01_15T12_30_14_677_arrays.csv"
shiftxyz_mu_atheta_ref = "2024_01_16T09_07_39_938_arrays.csv"
shiftxyz_mu_btheta = "2024_02_05T15_01_09_138_arrays.csv"
shiftxyz_mu_atheta = "2024_02_05T15_32_43_713_arrays.csv"
injectionxyz_mu0_btheta_ref = "2024_01_07T01_00_26_284_arrays.csv"
injectionxyz_mu0_atheta_ref = "2024_01_07T21_26_13_591_arrays.csv"
injectionxyz_mu0_btheta = "2024_02_05T15_55_31_819_arrays.csv"
injectionxyz_mu0_atheta = "2024_02_05T16_18_41_926_arrays.csv"
injectionxyz_mu_btheta_ref = "2024_01_07T21_48_47_893_arrays.csv"
injectionxyz_mu_atheta_ref = "2024_01_08T13_25_07_082_arrays.csv"
injectionxyz_mu_btheta = "2024_02_05T16_41_22_809_arrays.csv"
injectionxyz_mu_atheta = "2024_02_05T17_04_39_420_arrays.csv"

#s3
shiftyyy_mu_btheta_ref = strpath3a[5] 
shiftyyy_mu_atheta_ref = strpath3a[6]
shiftyyy_mu_btheta = "2024_02_06T16_31_07_255_arrays.csv"
shiftyyy_mu_atheta = "2024_02_06T16_57_59_478_arrays.csv"
shiftxxx_mu_btheta_ref = strpath3b[5] 
shiftxxx_mu_atheta_ref = strpath3b[6]
shiftxxx_mu_btheta = "2024_02_06T18_39_52_027_arrays.csv"
shiftxxx_mu_atheta = "2024_02_07T02_43_18_992_arrays.csv"
shiftxxz_mu_btheta_ref = strpath3c[5] 
shiftxxz_mu_atheta_ref = strpath3c[6]
shiftxxz_mu_btheta = "2024_02_07T10_19_26_927_arrays.csv"
shiftxxz_mu_atheta = "2024_02_07T10_49_24_335_arrays.csv"
injectionxxz_mu_btheta_ref = strpath3d[5] 
injectionxxz_mu_atheta_ref = strpath3d[6]
injectionxxz_mu_btheta = "2024_02_07T11_12_01_387_arrays.csv"
injectionxxz_mu_atheta = "2024_02_07T11_34_45_047_arrays.csv"

# %%
figS2 = lat_suppl2()
figS3 = lat_suppl3()

# %% [markdown]
# ### Figure S4

# %% [markdown]
# #### Compute

# %%
anglesweep(figS4a, cfigS4, method = :SHIFT)    
anglesweep(figS4a, cfigS4, method = :INJECTION)

# %% [markdown]
# #### Plot

# %%
path1 = "concatenated_shift.csv"
path2 = "concatenated_injection.csv"

# %%
figS4 = lat_suppl4(path1, path2)
